# %% [markdown]
# Clone o conjunto de dados necessário com base no conjunto de dados fornecido

# %%
#Clonando o conjunto de dados necessário
# !git clone https://github.com/ByjusBrazil/PRO_1-1_C113_HurricaneDamageDataset
# Out:
# Cloning into 'PRO_1-1_C113_HurricaneDamageDataset'...
# remote: Enumerating objects: 803, done.
# remote: Counting objects: 100% (803/803), done.
# remote: Compressing objects: 100% (800/800), done.
# remote: Total 803 (delta 1), reused 803 (delta 1), pack-reused 0
# Receiving objects: 100% (803/803), 2.07 MiB | 5.17 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# Exiba a primeira imagem do conjunto de dados de treinamento

# %%
#Exiba a imagem
from matplotlib import pyplot
from matplotlib.image import imread

training_damaged_image = "/content/PRO_1-1_C113_HurricaneDamageDataset/train/damage/image (1).jpeg"

# carregue os pixels da imagem
image = imread(training_damaged_image)

pyplot.title("danificado: Imagem 1")

# plote dados brutos de pixel
pyplot.imshow(image)

# exiba a imagem
pyplot.show()

# %% [markdown]
# Realize o aumento no conjunto de dados de treinamento

# %%
#zoom e inversão horizontal (ou qualquer técnica de aumento de sua escolha)

# %% [markdown]
# Visualize as imagens aumentadas em quatro subimagens

# %%
#Visualize a imagem pré-processada
